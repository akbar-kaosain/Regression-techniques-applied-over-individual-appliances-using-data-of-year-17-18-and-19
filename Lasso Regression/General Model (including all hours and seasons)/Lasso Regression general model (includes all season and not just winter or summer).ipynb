# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold

from numpy import mean
from numpy import std
from numpy import absolute

import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Image, display

mpl.rcParams['figure.figsize'] = (45,19)
mpl.rcParams['axes.grid'] = False


plt.style.use('seaborn')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Mohammad-Kaosain-Akbar/NILM-two-years-dataset/main/Data_Greener_all.csv')
df['Time'] = pd.to_datetime(df['Time'], infer_datetime_format=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               43824 non-null  datetime64[ns]
#  1   Ventilation        43824 non-null  float64
#  2   Sokets plug        43824 non-null  float64
#  3   Lighting           43824 non-null  float64
#  4   Other electricity  43824 non-null  float64
#  5   Cooling            43824 non-null  float64
#  6   Heating            43824 non-null  float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 2.3 MB

# %%
Total = df["Ventilation"] + df["Sokets plug"] + df["Lighting"] + df["Other electricity"] + df["Cooling"] + df["Heating"]
# https://www.kite.com/python/answers/how-to-sum-two-columns-in-a-pandas-dataframe-in-python

df["Total"] = Total

df
# Out:
#                      Time  Ventilation  Sokets plug  Lighting  \
# 0     2017-01-03 13:00:00         27.4         41.8      53.7
# 1     2017-01-03 14:00:00         21.6         37.5      50.9
# 2     2017-01-03 15:00:00         18.5         37.4      60.1
# 3     2017-01-03 16:00:00         29.7         38.0      52.6
# 4     2017-01-03 17:00:00         16.7         38.1      56.7
# ...                   ...          ...          ...       ...
# 43819 2022-01-03 08:00:00         59.3         17.9      16.6
# 43820 2022-01-03 09:00:00         71.9         20.6      33.1
# 43821 2022-01-03 10:00:00         90.5         30.9      47.8
# 43822 2022-01-03 11:00:00         94.0         33.9      52.2
# 43823 2022-01-03 12:00:00         95.3         28.5      36.3
#
#        Other electricity  Cooling  Heating   Total
# 0                   89.6    18.60    498.0  729.10
# 1                   64.6    61.90    500.0  736.50
# 2                   64.2    16.50    480.0  676.70
# 3                   43.2    19.80    390.0  573.30
# 4                   42.4    15.20    373.0  542.10
# ...                  ...      ...      ...     ...
# 43819              115.0    12.70    344.0  565.50
# 43820              149.0    11.90    399.0  685.50
# 43821              157.0    12.90    397.0  736.10
# 43822              155.0    15.40    345.0  695.50
# 43823              107.0     7.88    272.0  546.98
#
# [43824 rows x 8 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Image, display

mpl.rcParams['figure.figsize'] = (25,13)
mpl.rcParams['axes.grid'] = False

df.set_index('Time')[['Total','Ventilation',	'Sokets plug', 'Lighting',	'Other electricity',	'Cooling',	'Heating']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Time'>, <AxesSubplot:xlabel='Time'>,
#        <AxesSubplot:xlabel='Time'>, <AxesSubplot:xlabel='Time'>,
#        <AxesSubplot:xlabel='Time'>, <AxesSubplot:xlabel='Time'>,
#        <AxesSubplot:xlabel='Time'>], dtype=object)

# %%
df['Day']=df['Time'].dt.day
df['Month']=df['Time'].dt.month
df['Week']=df['Time'].dt.week # week of the year
df['Year']=df['Time'].dt.year
df['Hour']=df['Time'].dt.hour

df['Day of week']=df['Time'].dt.dayofweek
df['Day of year']=df['Time'].dt.dayofyear
df['Quarter']=df['Time'].dt.quarter 

df
# Out:
# /var/folders/z0/00nhgx7d2k97w_b2j6mn3qbc0000gn/T/ipykernel_1305/2527219698.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['Week']=df['Time'].dt.week # week of the year
#                      Time  Ventilation  Sokets plug  Lighting  \
# 0     2017-01-03 13:00:00         27.4         41.8      53.7
# 1     2017-01-03 14:00:00         21.6         37.5      50.9
# 2     2017-01-03 15:00:00         18.5         37.4      60.1
# 3     2017-01-03 16:00:00         29.7         38.0      52.6
# 4     2017-01-03 17:00:00         16.7         38.1      56.7
# ...                   ...          ...          ...       ...
# 43819 2022-01-03 08:00:00         59.3         17.9      16.6
# 43820 2022-01-03 09:00:00         71.9         20.6      33.1
# 43821 2022-01-03 10:00:00         90.5         30.9      47.8
# 43822 2022-01-03 11:00:00         94.0         33.9      52.2
# 43823 2022-01-03 12:00:00         95.3         28.5      36.3
#
#        Other electricity  Cooling  Heating   Total  Day  Month  Week  Year  \
# 0                   89.6    18.60    498.0  729.10    3      1     1  2017
# 1                   64.6    61.90    500.0  736.50    3      1     1  2017
# 2                   64.2    16.50    480.0  676.70    3      1     1  2017
# 3                   43.2    19.80    390.0  573.30    3      1     1  2017
# 4                   42.4    15.20    373.0  542.10    3      1     1  2017
# ...                  ...      ...      ...     ...  ...    ...   ...   ...
# 43819              115.0    12.70    344.0  565.50    3      1     1  2022
# 43820              149.0    11.90    399.0  685.50    3      1     1  2022
# 43821              157.0    12.90    397.0  736.10    3      1     1  2022
# 43822              155.0    15.40    345.0  695.50    3      1     1  2022
# 43823              107.0     7.88    272.0  546.98    3      1     1  2022
#
#        Hour  Day of week  Day of year  Quarter
# 0        13            1            3        1
# 1        14            1            3        1
# 2        15            1            3        1
# 3        16            1            3        1
# 4        17            1            3        1
# ...     ...          ...          ...      ...
# 43819     8            0            3        1
# 43820     9            0            3        1
# 43821    10            0            3        1
# 43822    11            0            3        1
# 43823    12            0            3        1
#
# [43824 rows x 16 columns]

# %%
train = df.loc[(df['Year'].isin([2017,2018]))]
test = df.loc[(df['Year'].isin([2019]))]

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn import linear_model


def model (X_train, Y_train, X_test, name):
    model = MultiOutputRegressor(linear_model.Lasso(alpha=0.1))
    model.fit(X_train, Y_train)
    
    # performing 10 fold cross validation of the model
    
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X_train, Y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)
    print('Afer 10 fold cross validation, Mean MAE of the appliance '+name+' is : %.3f \n\n' % (mean(scores)))
    
    pred = model.predict(X_test)
    return pred

# %%
def generate_graph(b,pred,test):
    predict = pred
    predict = np.asarray(predict).reshape(-1)

    tests = test
    tests = np.asarray(tests).reshape(-1)
    
    
    mpl.rcParams['figure.figsize'] = (25,15)
    plt.axis([0, 800, -10, 600])
    
    plt.plot(predict, label='Predicted Value') #plot the loss
    plt.plot(tests, label='True Value', linestyle='--') #plot the validation loss
    plt.legend(['Predicted Value', 'True Value'], loc='upper right', fontsize=16)
    plt.title('Graph for '+b+' Prediction', fontsize=16)
    plt.xlabel('Number of samples', fontsize=16)
    plt.ylabel('Consumption Values of the appliance', fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
   
    
    MAE = np.mean(np.abs(predict-tests))
    print("MAE of "+b+" is: ",MAE)
    print("\n\n")
    print("\n** The graph shows test versus predict of 800 samples from the total samples of the "+b+" appliance **\n")

# %%
def model_training (feature, name):
    
    print("##################################### Model for "+name+" ##########################################\n\n")
    
    X_train = train.iloc[:, [12,8,9,11,7,10,13,14,15]]
    Y_train = train.iloc[:, [feature]]

    X_test = test.iloc[:, [12,8,9,11,7,10,13,14,15]]
    Y_test = test.iloc[:, [feature]]
    
    model_training.Xtrain_shape = X_train.shape
    model_training.Ytrain_shape = Y_train.shape
    model_training.Xtest_shape = X_test.shape
    model_training.Ytest_shape = Y_test.shape
    
    pred = model(X_train, Y_train, X_test, name)
    Y_test = Y_test.to_numpy()
    
    generate_graph(name, pred, Y_test)

# %%
model_training(1,"Ventilation")
# Out:
# ##################################### Model for Ventilation ##########################################
#
#
# Afer 10 fold cross validation, Mean MAE of the appliance Ventilation is : 18.378
#
#
# MAE of Ventilation is:  20.136926004292086
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Ventilation appliance **

# %%
model_training(2,"Sokets plug")
# Out:
# ##################################### Model for Sokets plug ##########################################
#
#
# Afer 10 fold cross validation, Mean MAE of the appliance Sokets plug is : 5.182
#
#
# MAE of Sokets plug is:  6.6009633554601415
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Sokets plug appliance **

# %%
model_training(3,"Lighting")
# Out:
# ##################################### Model for Lighting ##########################################
#
#
# Afer 10 fold cross validation, Mean MAE of the appliance Lighting is : 8.719
#
#
# MAE of Lighting is:  10.183733069775544
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Lighting appliance **

# %%
model_training(4,"Other Electricity")
# Out:
# ##################################### Model for Other Electricity ##########################################
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2407318.037640445, tolerance: 4247.552217038487
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2253479.38251864, tolerance: 3843.4837847802337
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2209594.338321928, tolerance: 3836.8248454383656
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2208128.1917697564, tolerance: 3785.3150856141838
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2337771.2583759986, tolerance: 3848.099135157589
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1457069.0896616615, tolerance: 3775.0336668064597
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1854956.8159116525, tolerance: 3814.036446458822
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2148103.124419024, tolerance: 3819.8344018744247
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2507753.257657137, tolerance: 3832.23556014957
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2590940.300304709, tolerance: 3830.9719209933082
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2071710.6117731128, tolerance: 3842.0507233327776
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2257423.8208355717, tolerance: 3744.4764783427486
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2173342.647813296, tolerance: 3832.8079103009436
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2627339.3412593994, tolerance: 3835.2822809385307
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2346479.277499603, tolerance: 3862.320445168991
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1581375.9552385174, tolerance: 3849.693109187135
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2931735.9030261785, tolerance: 3827.3511464292947
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1526065.0320960246, tolerance: 3826.9076583624246
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2468955.7619418763, tolerance: 3845.1286253772687
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2079521.3897002432, tolerance: 3792.4184215019154
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1719337.863709217, tolerance: 3811.269898587461
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2724494.7834965046, tolerance: 3769.432405025783
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1867230.1109427568, tolerance: 3845.834090706325
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2328316.7614253797, tolerance: 3809.4125739145416
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3396636.53821099, tolerance: 3818.1013613373198
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1413433.6637291461, tolerance: 3840.2732658577556
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2311862.311674664, tolerance: 3827.964566253883
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2237215.809283953, tolerance: 3833.3042671902344
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1863898.2035897188, tolerance: 3838.146688912919
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2101146.099116765, tolerance: 3853.908728269616
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1876201.4063449707, tolerance: 3791.3650451164112
#   model = cd_fast.enet_coordinate_descent(
# Afer 10 fold cross validation, Mean MAE of the appliance Other Electricity is : 30.735
#
#
# MAE of Other Electricity is:  104.48397544542273
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Other Electricity appliance **

# %%
model_training(5,"Cooling")
# Out:
# ##################################### Model for Cooling ##########################################
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43888242.1598994, tolerance: 9874.592995300902
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38753378.654317155, tolerance: 8708.930149527927
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39307705.10905404, tolerance: 8835.285949406907
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39844673.1593597, tolerance: 8969.272918071618
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38746097.5868069, tolerance: 8710.06119082538
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39843586.34083105, tolerance: 8976.308147632413
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39522346.61339712, tolerance: 8878.795761150239
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40348330.88743961, tolerance: 9090.695243119617
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39497920.35089912, tolerance: 8898.849075741044
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39633539.48776671, tolerance: 8918.711528347305
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39460437.43871856, tolerance: 8883.894860021192
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39069864.82438474, tolerance: 8775.946568227939
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39277935.18780784, tolerance: 8835.725883569998
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38415439.762260266, tolerance: 8628.858264838893
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40251416.888686225, tolerance: 9069.349548809398
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39636166.60306829, tolerance: 8926.661959259689
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39859936.65685802, tolerance: 8955.572406935009
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39902391.016044065, tolerance: 8989.269643019867
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38685791.93956072, tolerance: 8695.715656227967
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39778715.869621515, tolerance: 8961.319868237142
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39662577.28011709, tolerance: 8943.74641975974
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40074284.813232176, tolerance: 9032.369903395302
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39562133.14653537, tolerance: 8916.677114206317
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39771602.88015746, tolerance: 8962.933557879547
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37705920.12475622, tolerance: 8450.925201116212
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40149139.553368874, tolerance: 9028.991447735913
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40263465.439807504, tolerance: 9078.283257294283
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38458219.922357224, tolerance: 8625.657901700777
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39970241.367021285, tolerance: 9007.503668230145
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39827636.375033565, tolerance: 8958.30366506464
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39562700.4308813, tolerance: 8897.24737616007
#   model = cd_fast.enet_coordinate_descent(
# Afer 10 fold cross validation, Mean MAE of the appliance Cooling is : 47.276
#
#
# MAE of Cooling is:  62.726801885208474
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Cooling appliance **

# %%
model_training(6,"Heating")
# Out:
# ##################################### Model for Heating ##########################################
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34115731.44057496, tolerance: 26389.874641087295
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30634854.2819666, tolerance: 23848.558146973955
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30746671.87054473, tolerance: 23679.71410769206
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31134400.556347314, tolerance: 23748.106639755155
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30884807.06481654, tolerance: 23603.072574526646
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30509588.993849855, tolerance: 23921.086850871678
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30692391.455967184, tolerance: 23631.00839237395
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30391252.98621338, tolerance: 23833.06880932222
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30626073.11069507, tolerance: 23939.777706444096
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30674661.977384165, tolerance: 23637.884227694496
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30836112.8548209, tolerance: 23891.765411258533
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30712024.320608508, tolerance: 23666.082844795408
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30439835.54661808, tolerance: 23678.48419765619
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30780283.959942408, tolerance: 24058.213581246364
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30308191.780778162, tolerance: 23593.352870788436
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30930729.20334704, tolerance: 24054.037937744866
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30953627.8639036, tolerance: 23704.26256800131
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30236405.040649228, tolerance: 23399.841813456384
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30709586.60434293, tolerance: 23599.31135377516
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30878192.216039777, tolerance: 23518.340508433754
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30941308.60187187, tolerance: 24008.677785437925
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30749232.671614505, tolerance: 23531.80085856295
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29954998.651639976, tolerance: 24170.6614228975
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30891707.78324924, tolerance: 23651.173649210567
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30735603.162985314, tolerance: 23824.173046108823
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30993661.01658579, tolerance: 23738.664044730205
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30999715.588839486, tolerance: 23810.77531578771
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30896485.984373156, tolerance: 23718.36341451078
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30255063.831343222, tolerance: 23737.155552952278
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30965637.487478647, tolerance: 23858.41496828565
#   model = cd_fast.enet_coordinate_descent(
# /Users/kaosainakbar/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30557777.139776897, tolerance: 23466.82835803278
#   model = cd_fast.enet_coordinate_descent(
# Afer 10 fold cross validation, Mean MAE of the appliance Heating is : 44.858
#
#
# MAE of Heating is:  93.06850130232097
#
#
#
#
# ** The graph shows test versus predict of 800 samples from the total samples of the Heating appliance **

# %% [markdown]
# ###  Figuring out the shapes of the train and test data

# %%
print("This was the shape X_train: \n\n ",model_training.Xtrain_shape)
print("\n\nThis was the shape Y_train: \n\n ",model_training.Ytrain_shape)
print("\n\nThis was the shape X_test: \n\n ",model_training.Xtest_shape)
print("\n\nThis was the shape Y_test: \n\n ",model_training.Xtest_shape)
# Out:
# This was the shape X_train:
#
#   (17459, 9)
#
#
# This was the shape Y_train:
#
#   (17459, 1)
#
#
# This was the shape X_test:
#
#   (8760, 9)
#
#
# This was the shape Y_test:
#
#   (8760, 9)
